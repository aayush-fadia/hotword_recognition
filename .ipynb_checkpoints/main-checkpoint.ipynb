# %%
# Small GPU Bugfix and all imports
import warnings
warnings.filterwarnings("ignore")

import tensorflow
physical_devices = tensorflow.config.list_physical_devices('GPU')
tensorflow.config.experimental.set_memory_growth(physical_devices[0], enable=True)

import tensorflow_datasets as tfds
import numpy as np
from tensorflow import  numpy_function
from tensorflow import convert_to_tensor
from tensorflow import float32
import tensorflow.keras as tf
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Convolution1D, Flatten, Dense
from tensorflow.keras.activations import softmax
from tensorflow.keras.callbacks import TensorBoard, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.models import load_model
import librosa
import os

# %%
# Loading Dataset
dataset = tfds.load(name="speech_commands", split="train")
dataset = dataset.shuffle(1024)
dataset_valid = tfds.load(name="speech_commands", split="validation")

# %%
# Dataset Prep Functions
@tensorflow.function
def pad_spectrogram(spec, len):
    zrs = tensorflow.zeros((spec.shape[0], len - spec.shape[1]), dtype=tensorflow.float32)
    padded = tensorflow.concat([zrs, spec], 1)
    return padded


def to_spectrogram(x):
    def mapping_function(audio, label):
        S = librosa.feature.melspectrogram(audio.astype(np.float32), sr=16000, n_fft=160, hop_length=400,
                                           n_mels=40)
        S_DB = librosa.power_to_db(S, ref=np.max)
        if S_DB.shape[1] != 41:
            S_DB = pad_spectrogram(S_DB, 41)
        S_DB = tensorflow.reshape(tensorflow.transpose(S_DB), (41, 40))
        x = convert_to_tensor(S_DB)
        y = convert_to_tensor(to_categorical(label, 12).astype(np.float32))
        return x, y

    audios, labels = numpy_function(mapping_function, [x['audio'], x['label']], [float32, float32])
    audios.set_shape((41, 40))
    labels.set_shape((12,))
    return audios, labels

def filter_predicate(x):
    label = x['label']
    return tf.backend.not_equal(label, 11)

# %%
# Apply Operations to Dataset
dataset = dataset.filter(filter_predicate)
dn = dataset.map(to_spectrogram)
dataset_valid = dataset_valid.filter(filter_predicate)
dataset_valid = dataset_valid.map(to_spectrogram)
# Out:
# WARNING:tensorflow:AutoGraph could not transform <function filter_predicate at 0x7f98dc4e6af0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Inconsistent ASTs detected. This is a bug. Cause:
# inconsistent values for field args: [<gast.gast.Name object at 0x7f98dc4afc10>] and []Diff:
# *** Original nodes
#
# --- Reparsed nodes
#
# ***************
#
# *** 8,22 ****
#
#   | | kw_defaults=[]
#   | | kwarg=None
#   | | defaults=[]
#   | body=[
#   | | FunctionDef:
#   | | | name=u"create_converted_entity"
#   | | | args=arguments:
# ! | | | | args=[
#   | | | | | Name:
#   | | | | | | id=u"ag__"
#   | | | | | | ctx=Param()
#   | | | | | | annotation=None
#   | | | | | | type_comment=None
#   | | | | | Name:
#   | | | | | | id=u"ag_source_map__"
# --- 8,23 ----
#
#   | | kw_defaults=[]
#   | | kwarg=None
#   | | defaults=[]
#   | body=[
#   | | FunctionDef:
#   | | | name=u"create_converted_entity"
#   | | | args=arguments:
# ! | | | | args=[]
# ! | | | | posonlyargs=[
#   | | | | | Name:
#   | | | | | | id=u"ag__"
#   | | | | | | ctx=Param()
#   | | | | | | annotation=None
#   | | | | | | type_comment=None
#   | | | | | Name:
#   | | | | | | id=u"ag_source_map__"
# ***************
#
# *** 25,56 ****
#
#   | | | | | | type_comment=None
#   | | | | | Name:
#   | | | | | | id=u"ag_module__"
#   | | | | | | ctx=Param()
#   | | | | | | annotation=None
#   | | | | | | type_comment=None
#   | | | | ]
# - | | | | posonlyargs=[]
#   | | | | vararg=None
#   | | | | kwonlyargs=[]
#   | | | | kw_defaults=[]
#   | | | | kwarg=None
#   | | | | defaults=[]
#   | | | body=[
#   | | | | FunctionDef:
#   | | | | | name=u"tf__filter_predicate"
#   | | | | | args=arguments:
# ! | | | | | | args=[
#   | | | | | | | Name:
#   | | | | | | | | id=u"x"
#   | | | | | | | | ctx=Param()
#   | | | | | | | | annotation=None
#   | | | | | | | | type_comment=None
#   | | | | | | ]
# - | | | | | | posonlyargs=[]
#   | | | | | | vararg=None
#   | | | | | | kwonlyargs=[]
#   | | | | | | kw_defaults=[]
#   | | | | | | kwarg=None
#   | | | | | | defaults=[]
#   | | | | | body=[
#   | | | | | | Assign:
# --- 26,56 ----
#
#   | | | | | | type_comment=None
#   | | | | | Name:
#   | | | | | | id=u"ag_module__"
#   | | | | | | ctx=Param()
#   | | | | | | annotation=None
#   | | | | | | type_comment=None
#   | | | | ]
#   | | | | vararg=None
#   | | | | kwonlyargs=[]
#   | | | | kw_defaults=[]
#   | | | | kwarg=None
#   | | | | defaults=[]
#   | | | body=[
#   | | | | FunctionDef:
#   | | | | | name=u"tf__filter_predicate"
#   | | | | | args=arguments:
# ! | | | | | | args=[]
# ! | | | | | | posonlyargs=[
#   | | | | | | | Name:
#   | | | | | | | | id=u"x"
#   | | | | | | | | ctx=Param()
#   | | | | | | | | annotation=None
#   | | | | | | | | type_comment=None
#   | | | | | | ]
#   | | | | | | vararg=None
#   | | | | | | kwonlyargs=[]
#   | | | | | | kw_defaults=[]
#   | | | | | | kwarg=None
#   | | | | | | defaults=[]
#   | | | | | body=[
#   | | | | | | Assign:
# WARNING:tensorflow:AutoGraph could not transform <function filter_predicate at 0x7f98dc4e6af0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Inconsistent ASTs detected. This is a bug. Cause:
# inconsistent values for field args: [<gast.gast.Name object at 0x7f98dc4afc10>] and []Diff:
# *** Original nodes
#
# --- Reparsed nodes
#
# ***************
#
# *** 8,22 ****
#
#   | | kw_defaults=[]
#   | | kwarg=None
#   | | defaults=[]
#   | body=[
#   | | FunctionDef:
#   | | | name=u"create_converted_entity"
#   | | | args=arguments:
# ! | | | | args=[
#   | | | | | Name:
#   | | | | | | id=u"ag__"
#   | | | | | | ctx=Param()
#   | | | | | | annotation=None
#   | | | | | | type_comment=None
#   | | | | | Name:
#   | | | | | | id=u"ag_source_map__"
# --- 8,23 ----
#
#   | | kw_defaults=[]
#   | | kwarg=None
#   | | defaults=[]
#   | body=[
#   | | FunctionDef:
#   | | | name=u"create_converted_entity"
#   | | | args=arguments:
# ! | | | | args=[]
# ! | | | | posonlyargs=[
#   | | | | | Name:
#   | | | | | | id=u"ag__"
#   | | | | | | ctx=Param()
#   | | | | | | annotation=None
#   | | | | | | type_comment=None
#   | | | | | Name:
#   | | | | | | id=u"ag_source_map__"
# ***************
#
# *** 25,56 ****
#
#   | | | | | | type_comment=None
#   | | | | | Name:
#   | | | | | | id=u"ag_module__"
#   | | | | | | ctx=Param()
#   | | | | | | annotation=None
#   | | | | | | type_comment=None
#   | | | | ]
# - | | | | posonlyargs=[]
#   | | | | vararg=None
#   | | | | kwonlyargs=[]
#   | | | | kw_defaults=[]
#   | | | | kwarg=None
#   | | | | defaults=[]
#   | | | body=[
#   | | | | FunctionDef:
#   | | | | | name=u"tf__filter_predicate"
#   | | | | | args=arguments:
# ! | | | | | | args=[
#   | | | | | | | Name:
#   | | | | | | | | id=u"x"
#   | | | | | | | | ctx=Param()
#   | | | | | | | | annotation=None
#   | | | | | | | | type_comment=None
#   | | | | | | ]
# - | | | | | | posonlyargs=[]
#   | | | | | | vararg=None
#   | | | | | | kwonlyargs=[]
#   | | | | | | kw_defaults=[]
#   | | | | | | kwarg=None
#   | | | | | | defaults=[]
#   | | | | | body=[
#   | | | | | | Assign:
# --- 26,56 ----
#
#   | | | | | | type_comment=None
#   | | | | | Name:
#   | | | | | | id=u"ag_module__"
#   | | | | | | ctx=Param()
#   | | | | | | annotation=None
#   | | | | | | type_comment=None
#   | | | | ]
#   | | | | vararg=None
#   | | | | kwonlyargs=[]
#   | | | | kw_defaults=[]
#   | | | | kwarg=None
#   | | | | defaults=[]
#   | | | body=[
#   | | | | FunctionDef:
#   | | | | | name=u"tf__filter_predicate"
#   | | | | | args=arguments:
# ! | | | | | | args=[]
# ! | | | | | | posonlyargs=[
#   | | | | | | | Name:
#   | | | | | | | | id=u"x"
#   | | | | | | | | ctx=Param()
#   | | | | | | | | annotation=None
#   | | | | | | | | type_comment=None
#   | | | | | | ]
#   | | | | | | vararg=None
#   | | | | | | kwonlyargs=[]
#   | | | | | | kw_defaults=[]
#   | | | | | | kwarg=None
#   | | | | | | defaults=[]
#   | | | | | body=[
#   | | | | | | Assign:
# WARNING: AutoGraph could not transform <function filter_predicate at 0x7f98dc4e6af0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Inconsistent ASTs detected. This is a bug. Cause:
# inconsistent values for field args: [<gast.gast.Name object at 0x7f98dc4afc10>] and []Diff:
# *** Original nodes
#
# --- Reparsed nodes
#
# ***************
#
# *** 8,22 ****
#
#   | | kw_defaults=[]
#   | | kwarg=None
#   | | defaults=[]
#   | body=[
#   | | FunctionDef:
#   | | | name=u"create_converted_entity"
#   | | | args=arguments:
# ! | | | | args=[
#   | | | | | Name:
#   | | | | | | id=u"ag__"
#   | | | | | | ctx=Param()
#   | | | | | | annotation=None
#   | | | | | | type_comment=None
#   | | | | | Name:
#   | | | | | | id=u"ag_source_map__"
# --- 8,23 ----
#
#   | | kw_defaults=[]
#   | | kwarg=None
#   | | defaults=[]
#   | body=[
#   | | FunctionDef:
#   | | | name=u"create_converted_entity"
#   | | | args=arguments:
# ! | | | | args=[]
# ! | | | | posonlyargs=[
#   | | | | | Name:
#   | | | | | | id=u"ag__"
#   | | | | | | ctx=Param()
#   | | | | | | annotation=None
#   | | | | | | type_comment=None
#   | | | | | Name:
#   | | | | | | id=u"ag_source_map__"
# ***************
#
# *** 25,56 ****
#
#   | | | | | | type_comment=None
#   | | | | | Name:
#   | | | | | | id=u"ag_module__"
#   | | | | | | ctx=Param()
#   | | | | | | annotation=None
#   | | | | | | type_comment=None
#   | | | | ]
# - | | | | posonlyargs=[]
#   | | | | vararg=None
#   | | | | kwonlyargs=[]
#   | | | | kw_defaults=[]
#   | | | | kwarg=None
#   | | | | defaults=[]
#   | | | body=[
#   | | | | FunctionDef:
#   | | | | | name=u"tf__filter_predicate"
#   | | | | | args=arguments:
# ! | | | | | | args=[
#   | | | | | | | Name:
#   | | | | | | | | id=u"x"
#   | | | | | | | | ctx=Param()
#   | | | | | | | | annotation=None
#   | | | | | | | | type_comment=None
#   | | | | | | ]
# - | | | | | | posonlyargs=[]
#   | | | | | | vararg=None
#   | | | | | | kwonlyargs=[]
#   | | | | | | kw_defaults=[]
#   | | | | | | kwarg=None
#   | | | | | | defaults=[]
#   | | | | | body=[
#   | | | | | | Assign:
# --- 26,56 ----
#
#   | | | | | | type_comment=None
#   | | | | | Name:
#   | | | | | | id=u"ag_module__"
#   | | | | | | ctx=Param()
#   | | | | | | annotation=None
#   | | | | | | type_comment=None
#   | | | | ]
#   | | | | vararg=None
#   | | | | kwonlyargs=[]
#   | | | | kw_defaults=[]
#   | | | | kwarg=None
#   | | | | defaults=[]
#   | | | body=[
#   | | | | FunctionDef:
#   | | | | | name=u"tf__filter_predicate"
#   | | | | | args=arguments:
# ! | | | | | | args=[]
# ! | | | | | | posonlyargs=[
#   | | | | | | | Name:
#   | | | | | | | | id=u"x"
#   | | | | | | | | ctx=Param()
#   | | | | | | | | annotation=None
#   | | | | | | | | type_comment=None
#   | | | | | | ]
#   | | | | | | vararg=None
#   | | | | | | kwonlyargs=[]
#   | | | | | | kw_defaults=[]
#   | | | | | | kwarg=None
#   | | | | | | defaults=[]
#   | | | | | body=[
#   | | | | | | Assign:
#
# WARNING:tensorflow:AutoGraph could not transform <function to_spectrogram at 0x7f98dc4e69d0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Inconsistent ASTs detected. This is a bug. Cause:
# inconsistent values for field args: [<gast.gast.Name object at 0x7f98dc3f78b0>] and []Diff:
# *** Original nodes
#
# --- Reparsed nodes
#
# ***************
#
# *** 8,22 ****
#
#   | | kw_defaults=[]
#   | | kwarg=None
#   | | defaults=[]
#   | body=[
#   | | FunctionDef:
#   | | | name=u"create_converted_entity"
#   | | | args=arguments:
# ! | | | | args=[
#   | | | | | Name:
#   | | | | | | id=u"ag__"
#   | | | | | | ctx=Param()
#   | | | | | | annotation=None
#   | | | | | | type_comment=None
#   | | | | | Name:
#   | | | | | | id=u"ag_source_map__"
# --- 8,23 ----
#
#   | | kw_defaults=[]
#   | | kwarg=None
#   | | defaults=[]
#   | body=[
#   | | FunctionDef:
#   | | | name=u"create_converted_entity"
#   | | | args=arguments:
# ! | | | | args=[]
# ! | | | | posonlyargs=[
#   | | | | | Name:
#   | | | | | | id=u"ag__"
#   | | | | | | ctx=Param()
#   | | | | | | annotation=None
#   | | | | | | type_comment=None
#   | | | | | Name:
#   | | | | | | id=u"ag_source_map__"
# ***************
#
# *** 25,56 ****
#
#   | | | | | | type_comment=None
#   | | | | | Name:
#   | | | | | | id=u"ag_module__"
#   | | | | | | ctx=Param()
#   | | | | | | annotation=None
#   | | | | | | type_comment=None
#   | | | | ]
# - | | | | posonlyargs=[]
#   | | | | vararg=None
#   | | | | kwonlyargs=[]
#   | | | | kw_defaults=[]
#   | | | | kwarg=None
#   | | | | defaults=[]
#   | | | body=[
#   | | | | FunctionDef:
#   | | | | | name=u"tf__to_spectrogram"
#   | | | | | args=arguments:
# ! | | | | | | args=[
#   | | | | | | | Name:
#   | | | | | | | | id=u"x"
#   | | | | | | | | ctx=Param()
#   | | | | | | | | annotation=None
#   | | | | | | | | type_comment=None
#   | | | | | | ]
# - | | | | | | posonlyargs=[]
#   | | | | | | vararg=None
#   | | | | | | kwonlyargs=[]
#   | | | | | | kw_defaults=[]
#   | | | | | | kwarg=None
#   | | | | | | defaults=[]
#   | | | | | body=[
#   | | | | | | Assign:
# --- 26,56 ----
#
#   | | | | | | type_comment=None
#   | | | | | Name:
#   | | | | | | id=u"ag_module__"
#   | | | | | | ctx=Param()
#   | | | | | | annotation=None
#   | | | | | | type_comment=None
#   | | | | ]
#   | | | | vararg=None
#   | | | | kwonlyargs=[]
#   | | | | kw_defaults=[]
#   | | | | kwarg=None
#   | | | | defaults=[]
#   | | | body=[
#   | | | | FunctionDef:
#   | | | | | name=u"tf__to_spectrogram"
#   | | | | | args=arguments:
# ! | | | | | | args=[]
# ! | | | | | | posonlyargs=[
#   | | | | | | | Name:
#   | | | | | | | | id=u"x"
#   | | | | | | | | ctx=Param()
#   | | | | | | | | annotation=None
#   | | | | | | | | type_comment=None
#   | | | | | | ]
#   | | | | | | vararg=None
#   | | | | | | kwonlyargs=[]
#   | | | | | | kw_defaults=[]
#   | | | | | | kwarg=None
#   | | | | | | defaults=[]
#   | | | | | body=[
#   | | | | | | Assign:
# ***************
#
# *** 118,144 ****
#
#   | | | | | | | | | | annotation=None
#   | | | | | | | | | | type_comment=None
#   | | | | | | | ]
#   | | | | | | | body=[
#   | | | | | | | | FunctionDef:
#   | | | | | | | | | name=u"mapping_function"
#   | | | | | | | | | args=arguments:
# ! | | | | | | | | | | args=[
#   | | | | | | | | | | | Name:
#   | | | | | | | | | | | | id=u"audio"
#   | | | | | | | | | | | | ctx=Param()
#   | | | | | | | | | | | | annotation=None
#   | | | | | | | | | | | | type_comment=None
#   | | | | | | | | | | | Name:
#   | | | | | | | | | | | | id=u"label"
#   | | | | | | | | | | | | ctx=Param()
#   | | | | | | | | | | | | annotation=None
#   | | | | | | | | | | | | type_comment=None
#   | | | | | | | | | | ]
# - | | | | | | | | | | posonlyargs=[]
#   | | | | | | | | | | vararg=None
#   | | | | | | | | | | kwonlyargs=[]
#   | | | | | | | | | | kw_defaults=[]
#   | | | | | | | | | | kwarg=None
#   | | | | | | | | | | defaults=[]
#   | | | | | | | | | body=[
#   | | | | | | | | | | Assign:
# --- 118,144 ----
#
#   | | | | | | | | | | annotation=None
#   | | | | | | | | | | type_comment=None
#   | | | | | | | ]
#   | | | | | | | body=[
#   | | | | | | | | FunctionDef:
#   | | | | | | | | | name=u"mapping_function"
#   | | | | | | | | | args=arguments:
# ! | | | | | | | | | | args=[]
# ! | | | | | | | | | | posonlyargs=[
#   | | | | | | | | | | | Name:
#   | | | | | | | | | | | | id=u"audio"
#   | | | | | | | | | | | | ctx=Param()
#   | | | | | | | | | | | | annotation=None
#   | | | | | | | | | | | | type_comment=None
#   | | | | | | | | | | | Name:
#   | | | | | | | | | | | | id=u"label"
#   | | | | | | | | | | | | ctx=Param()
#   | | | | | | | | | | | | annotation=None
#   | | | | | | | | | | | | type_comment=None
#   | | | | | | | | | | ]
#   | | | | | | | | | | vararg=None
#   | | | | | | | | | | kwonlyargs=[]
#   | | | | | | | | | | kw_defaults=[]
#   | | | | | | | | | | kwarg=None
#   | | | | | | | | | | defaults=[]
#   | | | | | | | | | body=[
#   | | | | | | | | | | Assign:
# ***************
#
# *** 395,423 ****
#
#   | | | | | | | | | | | | | ]
#   | | | | | | | | | | | | | decorator_list=[]
#   | | | | | | | | | | | | | returns=None
#   | | | | | | | | | | | | | type_comment=None
#   | | | | | | | | | | | | FunctionDef:
#   | | | | | | | | | | | | | name=u"set_state"
#   | | | | | | | | | | | | | args=arguments:
# ! | | | | | | | | | | | | | | args=[
#   | | | | | | | | | | | | | | | Name:
#   | | | | | | | | | | | | | | | | id=u"loop_vars"
#   | | | | | | | | | | | | | | | | ctx=Param()
#   | | | | | | | | | | | | | | | | annotation=None
#   | | | | | | | | | | | | | | | | type_comment=None
#   | | | | | | | | | | | | | | ]
# - | | | | | | | | | | | | | | posonlyargs=[]
#   | | | | | | | | | | | | | | vararg=None
#   | | | | | | | | | | | | | | kwonlyargs=[]
#   | | | | | | | | | | | | | | kw_defaults=[]
#   | | | | | | | | | | | | | | kwarg=None
#   | | | | | | | | | | | | | | defaults=[]
#   | | | | | | | | | | | | | body=[
# ! | | | | | | | | | | | | | | Pass()
#   | | | | | | | | | | | | | ]
#   | | | | | | | | | | | | | decorator_list=[]
#   | | | | | | | | | | | | | returns=None
#   | | | | | | | | | | | | | type_comment=None
#   | | | | | | | | | | | | FunctionDef:
#   | | | | | | | | | | | | | name=u"if_true"
#   | | | | | | | | | | | | | args=arguments:
# --- 395,423 ----
#
#   | | | | | | | | | | | | | ]
#   | | | | | | | | | | | | | decorator_list=[]
#   | | | | | | | | | | | | | returns=None
#   | | | | | | | | | | | | | type_comment=None
#   | | | | | | | | | | | | FunctionDef:
#   | | | | | | | | | | | | | name=u"set_state"
#   | | | | | | | | | | | | | args=arguments:
# ! | | | | | | | | | | | | | | args=[]
# ! | | | | | | | | | | | | | | posonlyargs=[
#   | | | | | | | | | | | | | | | Name:
#   | | | | | | | | | | | | | | | | id=u"loop_vars"
#   | | | | | | | | | | | | | | | | ctx=Param()
#   | | | | | | | | | | | | | | | | annotation=None
#   | | | | | | | | | | | | | | | | type_comment=None
#   | | | | | | | | | | | | | | ]
#   | | | | | | | | | | | | | | vararg=None
#   | | | | | | | | | | | | | | kwonlyargs=[]
#   | | | | | | | | | | | | | | kw_defaults=[]
#   | | | | | | | | | | | | | | kwarg=None
#   | | | | | | | | | | | | | | defaults=[]
#   | | | | | | | | | | | | | body=[
# ! | | | | | | | | | | | | | | Pass:
#   | | | | | | | | | | | | | ]
#   | | | | | | | | | | | | | decorator_list=[]
#   | | | | | | | | | | | | | returns=None
#   | | | | | | | | | | | | | type_comment=None
#   | | | | | | | | | | | | FunctionDef:
#   | | | | | | | | | | | | | name=u"if_true"
#   | | | | | | | | | | | | | args=arguments:
# WARNING:tensorflow:AutoGraph could not transform <function to_spectrogram at 0x7f98dc4e69d0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Inconsistent ASTs detected. This is a bug. Cause:
# inconsistent values for field args: [<gast.gast.Name object at 0x7f98dc3f78b0>] and []Diff:
# *** Original nodes
#
# --- Reparsed nodes
#
# ***************
#
# *** 8,22 ****
#
#   | | kw_defaults=[]
#   | | kwarg=None
#   | | defaults=[]
#   | body=[
#   | | FunctionDef:
#   | | | name=u"create_converted_entity"
#   | | | args=arguments:
# ! | | | | args=[
#   | | | | | Name:
#   | | | | | | id=u"ag__"
#   | | | | | | ctx=Param()
#   | | | | | | annotation=None
#   | | | | | | type_comment=None
#   | | | | | Name:
#   | | | | | | id=u"ag_source_map__"
# --- 8,23 ----
#
#   | | kw_defaults=[]
#   | | kwarg=None
#   | | defaults=[]
#   | body=[
#   | | FunctionDef:
#   | | | name=u"create_converted_entity"
#   | | | args=arguments:
# ! | | | | args=[]
# ! | | | | posonlyargs=[
#   | | | | | Name:
#   | | | | | | id=u"ag__"
#   | | | | | | ctx=Param()
#   | | | | | | annotation=None
#   | | | | | | type_comment=None
#   | | | | | Name:
#   | | | | | | id=u"ag_source_map__"
# ***************
#
# *** 25,56 ****
#
#   | | | | | | type_comment=None
#   | | | | | Name:
#   | | | | | | id=u"ag_module__"
#   | | | | | | ctx=Param()
#   | | | | | | annotation=None
#   | | | | | | type_comment=None
#   | | | | ]
# - | | | | posonlyargs=[]
#   | | | | vararg=None
#   | | | | kwonlyargs=[]
#   | | | | kw_defaults=[]
#   | | | | kwarg=None
#   | | | | defaults=[]
#   | | | body=[
#   | | | | FunctionDef:
#   | | | | | name=u"tf__to_spectrogram"
#   | | | | | args=arguments:
# ! | | | | | | args=[
#   | | | | | | | Name:
#   | | | | | | | | id=u"x"
#   | | | | | | | | ctx=Param()
#   | | | | | | | | annotation=None
#   | | | | | | | | type_comment=None
#   | | | | | | ]
# - | | | | | | posonlyargs=[]
#   | | | | | | vararg=None
#   | | | | | | kwonlyargs=[]
#   | | | | | | kw_defaults=[]
#   | | | | | | kwarg=None
#   | | | | | | defaults=[]
#   | | | | | body=[
#   | | | | | | Assign:
# --- 26,56 ----
#
#   | | | | | | type_comment=None
#   | | | | | Name:
#   | | | | | | id=u"ag_module__"
#   | | | | | | ctx=Param()
#   | | | | | | annotation=None
#   | | | | | | type_comment=None
#   | | | | ]
#   | | | | vararg=None
#   | | | | kwonlyargs=[]
#   | | | | kw_defaults=[]
#   | | | | kwarg=None
#   | | | | defaults=[]
#   | | | body=[
#   | | | | FunctionDef:
#   | | | | | name=u"tf__to_spectrogram"
#   | | | | | args=arguments:
# ! | | | | | | args=[]
# ! | | | | | | posonlyargs=[
#   | | | | | | | Name:
#   | | | | | | | | id=u"x"
#   | | | | | | | | ctx=Param()
#   | | | | | | | | annotation=None
#   | | | | | | | | type_comment=None
#   | | | | | | ]
#   | | | | | | vararg=None
#   | | | | | | kwonlyargs=[]
#   | | | | | | kw_defaults=[]
#   | | | | | | kwarg=None
#   | | | | | | defaults=[]
#   | | | | | body=[
#   | | | | | | Assign:
# ***************
#
# *** 118,144 ****
#
#   | | | | | | | | | | annotation=None
#   | | | | | | | | | | type_comment=None
#   | | | | | | | ]
#   | | | | | | | body=[
#   | | | | | | | | FunctionDef:
#   | | | | | | | | | name=u"mapping_function"
#   | | | | | | | | | args=arguments:
# ! | | | | | | | | | | args=[
#   | | | | | | | | | | | Name:
#   | | | | | | | | | | | | id=u"audio"
#   | | | | | | | | | | | | ctx=Param()
#   | | | | | | | | | | | | annotation=None
#   | | | | | | | | | | | | type_comment=None
#   | | | | | | | | | | | Name:
#   | | | | | | | | | | | | id=u"label"
#   | | | | | | | | | | | | ctx=Param()
#   | | | | | | | | | | | | annotation=None
#   | | | | | | | | | | | | type_comment=None
#   | | | | | | | | | | ]
# - | | | | | | | | | | posonlyargs=[]
#   | | | | | | | | | | vararg=None
#   | | | | | | | | | | kwonlyargs=[]
#   | | | | | | | | | | kw_defaults=[]
#   | | | | | | | | | | kwarg=None
#   | | | | | | | | | | defaults=[]
#   | | | | | | | | | body=[
#   | | | | | | | | | | Assign:
# --- 118,144 ----
#
#   | | | | | | | | | | annotation=None
#   | | | | | | | | | | type_comment=None
#   | | | | | | | ]
#   | | | | | | | body=[
#   | | | | | | | | FunctionDef:
#   | | | | | | | | | name=u"mapping_function"
#   | | | | | | | | | args=arguments:
# ! | | | | | | | | | | args=[]
# ! | | | | | | | | | | posonlyargs=[
#   | | | | | | | | | | | Name:
#   | | | | | | | | | | | | id=u"audio"
#   | | | | | | | | | | | | ctx=Param()
#   | | | | | | | | | | | | annotation=None
#   | | | | | | | | | | | | type_comment=None
#   | | | | | | | | | | | Name:
#   | | | | | | | | | | | | id=u"label"
#   | | | | | | | | | | | | ctx=Param()
#   | | | | | | | | | | | | annotation=None
#   | | | | | | | | | | | | type_comment=None
#   | | | | | | | | | | ]
#   | | | | | | | | | | vararg=None
#   | | | | | | | | | | kwonlyargs=[]
#   | | | | | | | | | | kw_defaults=[]
#   | | | | | | | | | | kwarg=None
#   | | | | | | | | | | defaults=[]
#   | | | | | | | | | body=[
#   | | | | | | | | | | Assign:
# ***************
#
# *** 395,423 ****
#
#   | | | | | | | | | | | | | ]
#   | | | | | | | | | | | | | decorator_list=[]
#   | | | | | | | | | | | | | returns=None
#   | | | | | | | | | | | | | type_comment=None
#   | | | | | | | | | | | | FunctionDef:
#   | | | | | | | | | | | | | name=u"set_state"
#   | | | | | | | | | | | | | args=arguments:
# ! | | | | | | | | | | | | | | args=[
#   | | | | | | | | | | | | | | | Name:
#   | | | | | | | | | | | | | | | | id=u"loop_vars"
#   | | | | | | | | | | | | | | | | ctx=Param()
#   | | | | | | | | | | | | | | | | annotation=None
#   | | | | | | | | | | | | | | | | type_comment=None
#   | | | | | | | | | | | | | | ]
# - | | | | | | | | | | | | | | posonlyargs=[]
#   | | | | | | | | | | | | | | vararg=None
#   | | | | | | | | | | | | | | kwonlyargs=[]
#   | | | | | | | | | | | | | | kw_defaults=[]
#   | | | | | | | | | | | | | | kwarg=None
#   | | | | | | | | | | | | | | defaults=[]
#   | | | | | | | | | | | | | body=[
# ! | | | | | | | | | | | | | | Pass()
#   | | | | | | | | | | | | | ]
#   | | | | | | | | | | | | | decorator_list=[]
#   | | | | | | | | | | | | | returns=None
#   | | | | | | | | | | | | | type_comment=None
#   | | | | | | | | | | | | FunctionDef:
#   | | | | | | | | | | | | | name=u"if_true"
#   | | | | | | | | | | | | | args=arguments:
# --- 395,423 ----
#
#   | | | | | | | | | | | | | ]
#   | | | | | | | | | | | | | decorator_list=[]
#   | | | | | | | | | | | | | returns=None
#   | | | | | | | | | | | | | type_comment=None
#   | | | | | | | | | | | | FunctionDef:
#   | | | | | | | | | | | | | name=u"set_state"
#   | | | | | | | | | | | | | args=arguments:
# ! | | | | | | | | | | | | | | args=[]
# ! | | | | | | | | | | | | | | posonlyargs=[
#   | | | | | | | | | | | | | | | Name:
#   | | | | | | | | | | | | | | | | id=u"loop_vars"
#   | | | | | | | | | | | | | | | | ctx=Param()
#   | | | | | | | | | | | | | | | | annotation=None
#   | | | | | | | | | | | | | | | | type_comment=None
#   | | | | | | | | | | | | | | ]
#   | | | | | | | | | | | | | | vararg=None
#   | | | | | | | | | | | | | | kwonlyargs=[]
#   | | | | | | | | | | | | | | kw_defaults=[]
#   | | | | | | | | | | | | | | kwarg=None
#   | | | | | | | | | | | | | | defaults=[]
#   | | | | | | | | | | | | | body=[
# ! | | | | | | | | | | | | | | Pass:
#   | | | | | | | | | | | | | ]
#   | | | | | | | | | | | | | decorator_list=[]
#   | | | | | | | | | | | | | returns=None
#   | | | | | | | | | | | | | type_comment=None
#   | | | | | | | | | | | | FunctionDef:
#   | | | | | | | | | | | | | name=u"if_true"
#   | | | | | | | | | | | | | args=arguments:
# WARNING: AutoGraph could not transform <function to_spectrogram at 0x7f98dc4e69d0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Inconsistent ASTs detected. This is a bug. Cause:
# inconsistent values for field args: [<gast.gast.Name object at 0x7f98dc3f78b0>] and []Diff:
# *** Original nodes
#
# --- Reparsed nodes
#
# ***************
#
# *** 8,22 ****
#
#   | | kw_defaults=[]
#   | | kwarg=None
#   | | defaults=[]
#   | body=[
#   | | FunctionDef:
#   | | | name=u"create_converted_entity"
#   | | | args=arguments:
# ! | | | | args=[
#   | | | | | Name:
#   | | | | | | id=u"ag__"
#   | | | | | | ctx=Param()
#   | | | | | | annotation=None
#   | | | | | | type_comment=None
#   | | | | | Name:
#   | | | | | | id=u"ag_source_map__"
# --- 8,23 ----
#
#   | | kw_defaults=[]
#   | | kwarg=None
#   | | defaults=[]
#   | body=[
#   | | FunctionDef:
#   | | | name=u"create_converted_entity"
#   | | | args=arguments:
# ! | | | | args=[]
# ! | | | | posonlyargs=[
#   | | | | | Name:
#   | | | | | | id=u"ag__"
#   | | | | | | ctx=Param()
#   | | | | | | annotation=None
#   | | | | | | type_comment=None
#   | | | | | Name:
#   | | | | | | id=u"ag_source_map__"
# ***************
#
# *** 25,56 ****
#
#   | | | | | | type_comment=None
#   | | | | | Name:
#   | | | | | | id=u"ag_module__"
#   | | | | | | ctx=Param()
#   | | | | | | annotation=None
#   | | | | | | type_comment=None
#   | | | | ]
# - | | | | posonlyargs=[]
#   | | | | vararg=None
#   | | | | kwonlyargs=[]
#   | | | | kw_defaults=[]
#   | | | | kwarg=None
#   | | | | defaults=[]
#   | | | body=[
#   | | | | FunctionDef:
#   | | | | | name=u"tf__to_spectrogram"
#   | | | | | args=arguments:
# ! | | | | | | args=[
#   | | | | | | | Name:
#   | | | | | | | | id=u"x"
#   | | | | | | | | ctx=Param()
#   | | | | | | | | annotation=None
#   | | | | | | | | type_comment=None
#   | | | | | | ]
# - | | | | | | posonlyargs=[]
#   | | | | | | vararg=None
#   | | | | | | kwonlyargs=[]
#   | | | | | | kw_defaults=[]
#   | | | | | | kwarg=None
#   | | | | | | defaults=[]
#   | | | | | body=[
#   | | | | | | Assign:
# --- 26,56 ----
#
#   | | | | | | type_comment=None
#   | | | | | Name:
#   | | | | | | id=u"ag_module__"
#   | | | | | | ctx=Param()
#   | | | | | | annotation=None
#   | | | | | | type_comment=None
#   | | | | ]
#   | | | | vararg=None
#   | | | | kwonlyargs=[]
#   | | | | kw_defaults=[]
#   | | | | kwarg=None
#   | | | | defaults=[]
#   | | | body=[
#   | | | | FunctionDef:
#   | | | | | name=u"tf__to_spectrogram"
#   | | | | | args=arguments:
# ! | | | | | | args=[]
# ! | | | | | | posonlyargs=[
#   | | | | | | | Name:
#   | | | | | | | | id=u"x"
#   | | | | | | | | ctx=Param()
#   | | | | | | | | annotation=None
#   | | | | | | | | type_comment=None
#   | | | | | | ]
#   | | | | | | vararg=None
#   | | | | | | kwonlyargs=[]
#   | | | | | | kw_defaults=[]
#   | | | | | | kwarg=None
#   | | | | | | defaults=[]
#   | | | | | body=[
#   | | | | | | Assign:
# ***************
#
# *** 118,144 ****
#
#   | | | | | | | | | | annotation=None
#   | | | | | | | | | | type_comment=None
#   | | | | | | | ]
#   | | | | | | | body=[
#   | | | | | | | | FunctionDef:
#   | | | | | | | | | name=u"mapping_function"
#   | | | | | | | | | args=arguments:
# ! | | | | | | | | | | args=[
#   | | | | | | | | | | | Name:
#   | | | | | | | | | | | | id=u"audio"
#   | | | | | | | | | | | | ctx=Param()
#   | | | | | | | | | | | | annotation=None
#   | | | | | | | | | | | | type_comment=None
#   | | | | | | | | | | | Name:
#   | | | | | | | | | | | | id=u"label"
#   | | | | | | | | | | | | ctx=Param()
#   | | | | | | | | | | | | annotation=None
#   | | | | | | | | | | | | type_comment=None
#   | | | | | | | | | | ]
# - | | | | | | | | | | posonlyargs=[]
#   | | | | | | | | | | vararg=None
#   | | | | | | | | | | kwonlyargs=[]
#   | | | | | | | | | | kw_defaults=[]
#   | | | | | | | | | | kwarg=None
#   | | | | | | | | | | defaults=[]
#   | | | | | | | | | body=[
#   | | | | | | | | | | Assign:
# --- 118,144 ----
#
#   | | | | | | | | | | annotation=None
#   | | | | | | | | | | type_comment=None
#   | | | | | | | ]
#   | | | | | | | body=[
#   | | | | | | | | FunctionDef:
#   | | | | | | | | | name=u"mapping_function"
#   | | | | | | | | | args=arguments:
# ! | | | | | | | | | | args=[]
# ! | | | | | | | | | | posonlyargs=[
#   | | | | | | | | | | | Name:
#   | | | | | | | | | | | | id=u"audio"
#   | | | | | | | | | | | | ctx=Param()
#   | | | | | | | | | | | | annotation=None
#   | | | | | | | | | | | | type_comment=None
#   | | | | | | | | | | | Name:
#   | | | | | | | | | | | | id=u"label"
#   | | | | | | | | | | | | ctx=Param()
#   | | | | | | | | | | | | annotation=None
#   | | | | | | | | | | | | type_comment=None
#   | | | | | | | | | | ]
#   | | | | | | | | | | vararg=None
#   | | | | | | | | | | kwonlyargs=[]
#   | | | | | | | | | | kw_defaults=[]
#   | | | | | | | | | | kwarg=None
#   | | | | | | | | | | defaults=[]
#   | | | | | | | | | body=[
#   | | | | | | | | | | Assign:
# ***************
#
# *** 395,423 ****
#
#   | | | | | | | | | | | | | ]
#   | | | | | | | | | | | | | decorator_list=[]
#   | | | | | | | | | | | | | returns=None
#   | | | | | | | | | | | | | type_comment=None
#   | | | | | | | | | | | | FunctionDef:
#   | | | | | | | | | | | | | name=u"set_state"
#   | | | | | | | | | | | | | args=arguments:
# ! | | | | | | | | | | | | | | args=[
#   | | | | | | | | | | | | | | | Name:
#   | | | | | | | | | | | | | | | | id=u"loop_vars"
#   | | | | | | | | | | | | | | | | ctx=Param()
#   | | | | | | | | | | | | | | | | annotation=None
#   | | | | | | | | | | | | | | | | type_comment=None
#   | | | | | | | | | | | | | | ]
# - | | | | | | | | | | | | | | posonlyargs=[]
#   | | | | | | | | | | | | | | vararg=None
#   | | | | | | | | | | | | | | kwonlyargs=[]
#   | | | | | | | | | | | | | | kw_defaults=[]
#   | | | | | | | | | | | | | | kwarg=None
#   | | | | | | | | | | | | | | defaults=[]
#   | | | | | | | | | | | | | body=[
# ! | | | | | | | | | | | | | | Pass()
#   | | | | | | | | | | | | | ]
#   | | | | | | | | | | | | | decorator_list=[]
#   | | | | | | | | | | | | | returns=None
#   | | | | | | | | | | | | | type_comment=None
#   | | | | | | | | | | | | FunctionDef:
#   | | | | | | | | | | | | | name=u"if_true"
#   | | | | | | | | | | | | | args=arguments:
# --- 395,423 ----
#
#   | | | | | | | | | | | | | ]
#   | | | | | | | | | | | | | decorator_list=[]
#   | | | | | | | | | | | | | returns=None
#   | | | | | | | | | | | | | type_comment=None
#   | | | | | | | | | | | | FunctionDef:
#   | | | | | | | | | | | | | name=u"set_state"
#   | | | | | | | | | | | | | args=arguments:
# ! | | | | | | | | | | | | | | args=[]
# ! | | | | | | | | | | | | | | posonlyargs=[
#   | | | | | | | | | | | | | | | Name:
#   | | | | | | | | | | | | | | | | id=u"loop_vars"
#   | | | | | | | | | | | | | | | | ctx=Param()
#   | | | | | | | | | | | | | | | | annotation=None
#   | | | | | | | | | | | | | | | | type_comment=None
#   | | | | | | | | | | | | | | ]
#   | | | | | | | | | | | | | | vararg=None
#   | | | | | | | | | | | | | | kwonlyargs=[]
#   | | | | | | | | | | | | | | kw_defaults=[]
#   | | | | | | | | | | | | | | kwarg=None
#   | | | | | | | | | | | | | | defaults=[]
#   | | | | | | | | | | | | | body=[
# ! | | | | | | | | | | | | | | Pass:
#   | | | | | | | | | | | | | ]
#   | | | | | | | | | | | | | decorator_list=[]
#   | | | | | | | | | | | | | returns=None
#   | | | | | | | | | | | | | type_comment=None
#   | | | | | | | | | | | | FunctionDef:
#   | | | | | | | | | | | | | name=u"if_true"
#   | | | | | | | | | | | | | args=arguments:

# %%
# Visualize Dataset
from librosa.display import specshow
import matplotlib.pyplot as plt

for x, y in dn.take(1):
    specshow(x.numpy(), sr=16000, hop_length=400, x_axis='time', y_axis='mel')
    plt.colorbar(format='%+2.0f dB')
    plt.show()

# %%
# Train Run prep
RUN_NAME = 'conv1d_nounknowns'
tbcallback = TensorBoard(log_dir='logs/' + RUN_NAME)
lr_reduction_callback = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10, verbose=0, mode='auto', min_delta=0.0001, cooldown=0, min_lr=0)
if 'saved_models' not in os.listdir('.'):
    os.mkdir('saved_models')
checkpointcallback = ModelCheckpoint('saved_models/'+RUN_NAME + '.h5', monitor='train-acc', save_best_only=False)
dn = dn.batch(64)
dataset_valid = dataset_valid.batch(64)

# %%
# Model Definition
model = tf.Sequential()
model.add(Convolution1D(82, 5, input_shape=(41, 40)))
model.add(Convolution1D(20, 3))
model.add(Flatten())
model.add(Dense(32))
model.add(Dense(128))
model.add(Dense(12, activation=softmax))
model.summary()
model.compile(tf.optimizers.Adam(0.0001), loss=tf.losses.categorical_crossentropy, metrics=['acc'])
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 37, 82)            16482
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 35, 20)            4940
# _________________________________________________________________
# flatten (Flatten)            (None, 700)               0
# _________________________________________________________________
# dense (Dense)                (None, 32)                22432
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               4224
# _________________________________________________________________
# dense_2 (Dense)              (None, 12)                1548
# =================================================================
# Total params: 49,626
# Trainable params: 49,626
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Model Training
model.fit(dn, callbacks=[tbcallback, checkpointcallback, lr_reduction_callback], epochs=512, validation_data=dataset_valid, verbose=False)
# Out:
# WARNING:tensorflow:AutoGraph could not transform <function pad_spectrogram at 0x7f98dc4e68b0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Inconsistent ASTs detected. This is a bug. Cause:
# inconsistent values for field args: [<gast.gast.Name object at 0x7f9878c2e520>, <gast.gast.Name object at 0x7f9878c410a0>] and []Diff:
# *** Original nodes
#
# --- Reparsed nodes
#
# ***************
#
# *** 8,22 ****
#
#   | | kw_defaults=[]
#   | | kwarg=None
#   | | defaults=[]
#   | body=[
#   | | FunctionDef:
#   | | | name=u"create_converted_entity"
#   | | | args=arguments:
# ! | | | | args=[
#   | | | | | Name:
#   | | | | | | id=u"ag__"
#   | | | | | | ctx=Param()
#   | | | | | | annotation=None
#   | | | | | | type_comment=None
#   | | | | | Name:
#   | | | | | | id=u"ag_source_map__"
# --- 8,23 ----
#
#   | | kw_defaults=[]
#   | | kwarg=None
#   | | defaults=[]
#   | body=[
#   | | FunctionDef:
#   | | | name=u"create_converted_entity"
#   | | | args=arguments:
# ! | | | | args=[]
# ! | | | | posonlyargs=[
#   | | | | | Name:
#   | | | | | | id=u"ag__"
#   | | | | | | ctx=Param()
#   | | | | | | annotation=None
#   | | | | | | type_comment=None
#   | | | | | Name:
#   | | | | | | id=u"ag_source_map__"
# ***************
#
# *** 25,61 ****
#
#   | | | | | | type_comment=None
#   | | | | | Name:
#   | | | | | | id=u"ag_module__"
#   | | | | | | ctx=Param()
#   | | | | | | annotation=None
#   | | | | | | type_comment=None
#   | | | | ]
# - | | | | posonlyargs=[]
#   | | | | vararg=None
#   | | | | kwonlyargs=[]
#   | | | | kw_defaults=[]
#   | | | | kwarg=None
#   | | | | defaults=[]
#   | | | body=[
#   | | | | FunctionDef:
#   | | | | | name=u"tf__pad_spectrogram"
#   | | | | | args=arguments:
# ! | | | | | | args=[
#   | | | | | | | Name:
#   | | | | | | | | id=u"spec"
#   | | | | | | | | ctx=Param()
#   | | | | | | | | annotation=None
#   | | | | | | | | type_comment=None
#   | | | | | | | Name:
#   | | | | | | | | id=u"len"
#   | | | | | | | | ctx=Param()
#   | | | | | | | | annotation=None
#   | | | | | | | | type_comment=None
#   | | | | | | ]
# - | | | | | | posonlyargs=[]
#   | | | | | | vararg=None
#   | | | | | | kwonlyargs=[]
#   | | | | | | kw_defaults=[]
#   | | | | | | kwarg=None
#   | | | | | | defaults=[]
#   | | | | | body=[
#   | | | | | | Assign:
# --- 26,61 ----
#
#   | | | | | | type_comment=None
#   | | | | | Name:
#   | | | | | | id=u"ag_module__"
#   | | | | | | ctx=Param()
#   | | | | | | annotation=None
#   | | | | | | type_comment=None
#   | | | | ]
#   | | | | vararg=None
#   | | | | kwonlyargs=[]
#   | | | | kw_defaults=[]
#   | | | | kwarg=None
#   | | | | defaults=[]
#   | | | body=[
#   | | | | FunctionDef:
#   | | | | | name=u"tf__pad_spectrogram"
#   | | | | | args=arguments:
# ! | | | | | | args=[]
# ! | | | | | | posonlyargs=[
#   | | | | | | | Name:
#   | | | | | | | | id=u"spec"
#   | | | | | | | | ctx=Param()
#   | | | | | | | | annotation=None
#   | | | | | | | | type_comment=None
#   | | | | | | | Name:
#   | | | | | | | | id=u"len"
#   | | | | | | | | ctx=Param()
#   | | | | | | | | annotation=None
#   | | | | | | | | type_comment=None
#   | | | | | | ]
#   | | | | | | vararg=None
#   | | | | | | kwonlyargs=[]
#   | | | | | | kw_defaults=[]
#   | | | | | | kwarg=None
#   | | | | | | defaults=[]
#   | | | | | body=[
#   | | | | | | Assign:
# WARNING:tensorflow:AutoGraph could not transform <function pad_spectrogram at 0x7f98dc4e68b0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Inconsistent ASTs detected. This is a bug. Cause:
# inconsistent values for field args: [<gast.gast.Name object at 0x7f9878c2e520>, <gast.gast.Name object at 0x7f9878c410a0>] and []Diff:
# *** Original nodes
#
# --- Reparsed nodes
#
# ***************
#
# *** 8,22 ****
#
#   | | kw_defaults=[]
#   | | kwarg=None
#   | | defaults=[]
#   | body=[
#   | | FunctionDef:
#   | | | name=u"create_converted_entity"
#   | | | args=arguments:
# ! | | | | args=[
#   | | | | | Name:
#   | | | | | | id=u"ag__"
#   | | | | | | ctx=Param()
#   | | | | | | annotation=None
#   | | | | | | type_comment=None
#   | | | | | Name:
#   | | | | | | id=u"ag_source_map__"
# --- 8,23 ----
#
#   | | kw_defaults=[]
#   | | kwarg=None
#   | | defaults=[]
#   | body=[
#   | | FunctionDef:
#   | | | name=u"create_converted_entity"
#   | | | args=arguments:
# ! | | | | args=[]
# ! | | | | posonlyargs=[
#   | | | | | Name:
#   | | | | | | id=u"ag__"
#   | | | | | | ctx=Param()
#   | | | | | | annotation=None
#   | | | | | | type_comment=None
#   | | | | | Name:
#   | | | | | | id=u"ag_source_map__"
# ***************
#
# *** 25,61 ****
#
#   | | | | | | type_comment=None
#   | | | | | Name:
#   | | | | | | id=u"ag_module__"
#   | | | | | | ctx=Param()
#   | | | | | | annotation=None
#   | | | | | | type_comment=None
#   | | | | ]
# - | | | | posonlyargs=[]
#   | | | | vararg=None
#   | | | | kwonlyargs=[]
#   | | | | kw_defaults=[]
#   | | | | kwarg=None
#   | | | | defaults=[]
#   | | | body=[
#   | | | | FunctionDef:
#   | | | | | name=u"tf__pad_spectrogram"
#   | | | | | args=arguments:
# ! | | | | | | args=[
#   | | | | | | | Name:
#   | | | | | | | | id=u"spec"
#   | | | | | | | | ctx=Param()
#   | | | | | | | | annotation=None
#   | | | | | | | | type_comment=None
#   | | | | | | | Name:
#   | | | | | | | | id=u"len"
#   | | | | | | | | ctx=Param()
#   | | | | | | | | annotation=None
#   | | | | | | | | type_comment=None
#   | | | | | | ]
# - | | | | | | posonlyargs=[]
#   | | | | | | vararg=None
#   | | | | | | kwonlyargs=[]
#   | | | | | | kw_defaults=[]
#   | | | | | | kwarg=None
#   | | | | | | defaults=[]
#   | | | | | body=[
#   | | | | | | Assign:
# --- 26,61 ----
#
#   | | | | | | type_comment=None
#   | | | | | Name:
#   | | | | | | id=u"ag_module__"
#   | | | | | | ctx=Param()
#   | | | | | | annotation=None
#   | | | | | | type_comment=None
#   | | | | ]
#   | | | | vararg=None
#   | | | | kwonlyargs=[]
#   | | | | kw_defaults=[]
#   | | | | kwarg=None
#   | | | | defaults=[]
#   | | | body=[
#   | | | | FunctionDef:
#   | | | | | name=u"tf__pad_spectrogram"
#   | | | | | args=arguments:
# ! | | | | | | args=[]
# ! | | | | | | posonlyargs=[
#   | | | | | | | Name:
#   | | | | | | | | id=u"spec"
#   | | | | | | | | ctx=Param()
#   | | | | | | | | annotation=None
#   | | | | | | | | type_comment=None
#   | | | | | | | Name:
#   | | | | | | | | id=u"len"
#   | | | | | | | | ctx=Param()
#   | | | | | | | | annotation=None
#   | | | | | | | | type_comment=None
#   | | | | | | ]
#   | | | | | | vararg=None
#   | | | | | | kwonlyargs=[]
#   | | | | | | kw_defaults=[]
#   | | | | | | kwarg=None
#   | | | | | | defaults=[]
#   | | | | | body=[
#   | | | | | | Assign:
# WARNING: AutoGraph could not transform <function pad_spectrogram at 0x7f98dc4e68b0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Inconsistent ASTs detected. This is a bug. Cause:
# inconsistent values for field args: [<gast.gast.Name object at 0x7f9878c2e520>, <gast.gast.Name object at 0x7f9878c410a0>] and []Diff:
# *** Original nodes
#
# --- Reparsed nodes
#
# ***************
#
# *** 8,22 ****
#
#   | | kw_defaults=[]
#   | | kwarg=None
#   | | defaults=[]
#   | body=[
#   | | FunctionDef:
#   | | | name=u"create_converted_entity"
#   | | | args=arguments:
# ! | | | | args=[
#   | | | | | Name:
#   | | | | | | id=u"ag__"
#   | | | | | | ctx=Param()
#   | | | | | | annotation=None
#   | | | | | | type_comment=None
#   | | | | | Name:
#   | | | | | | id=u"ag_source_map__"
# --- 8,23 ----
#
#   | | kw_defaults=[]
#   | | kwarg=None
#   | | defaults=[]
#   | body=[
#   | | FunctionDef:
#   | | | name=u"create_converted_entity"
#   | | | args=arguments:
# ! | | | | args=[]
# ! | | | | posonlyargs=[
#   | | | | | Name:
#   | | | | | | id=u"ag__"
#   | | | | | | ctx=Param()
#   | | | | | | annotation=None
#   | | | | | | type_comment=None
#   | | | | | Name:
#   | | | | | | id=u"ag_source_map__"
# ***************
#
# *** 25,61 ****
#
#   | | | | | | type_comment=None
#   | | | | | Name:
#   | | | | | | id=u"ag_module__"
#   | | | | | | ctx=Param()
#   | | | | | | annotation=None
#   | | | | | | type_comment=None
#   | | | | ]
# - | | | | posonlyargs=[]
#   | | | | vararg=None
#   | | | | kwonlyargs=[]
#   | | | | kw_defaults=[]
#   | | | | kwarg=None
#   | | | | defaults=[]
#   | | | body=[
#   | | | | FunctionDef:
#   | | | | | name=u"tf__pad_spectrogram"
#   | | | | | args=arguments:
# ! | | | | | | args=[
#   | | | | | | | Name:
#   | | | | | | | | id=u"spec"
#   | | | | | | | | ctx=Param()
#   | | | | | | | | annotation=None
#   | | | | | | | | type_comment=None
#   | | | | | | | Name:
#   | | | | | | | | id=u"len"
#   | | | | | | | | ctx=Param()
#   | | | | | | | | annotation=None
#   | | | | | | | | type_comment=None
#   | | | | | | ]
# - | | | | | | posonlyargs=[]
#   | | | | | | vararg=None
#   | | | | | | kwonlyargs=[]
#   | | | | | | kw_defaults=[]
#   | | | | | | kwarg=None
#   | | | | | | defaults=[]
#   | | | | | body=[
#   | | | | | | Assign:
# --- 26,61 ----
#
#   | | | | | | type_comment=None
#   | | | | | Name:
#   | | | | | | id=u"ag_module__"
#   | | | | | | ctx=Param()
#   | | | | | | annotation=None
#   | | | | | | type_comment=None
#   | | | | ]
#   | | | | vararg=None
#   | | | | kwonlyargs=[]
#   | | | | kw_defaults=[]
#   | | | | kwarg=None
#   | | | | defaults=[]
#   | | | body=[
#   | | | | FunctionDef:
#   | | | | | name=u"tf__pad_spectrogram"
#   | | | | | args=arguments:
# ! | | | | | | args=[]
# ! | | | | | | posonlyargs=[
#   | | | | | | | Name:
#   | | | | | | | | id=u"spec"
#   | | | | | | | | ctx=Param()
#   | | | | | | | | annotation=None
#   | | | | | | | | type_comment=None
#   | | | | | | | Name:
#   | | | | | | | | id=u"len"
#   | | | | | | | | ctx=Param()
#   | | | | | | | | annotation=None
#   | | | | | | | | type_comment=None
#   | | | | | | ]
#   | | | | | | vararg=None
#   | | | | | | kwonlyargs=[]
#   | | | | | | kw_defaults=[]
#   | | | | | | kwarg=None
#   | | | | | | defaults=[]
#   | | | | | body=[
#   | | | | | | Assign:
#
# WARNING:tensorflow:5 out of the last 6 calls to <function pad_spectrogram at 0x7f98dc4e68b0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:5 out of the last 6 calls to <function pad_spectrogram at 0x7f98dc4e68b0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:6 out of the last 7 calls to <function pad_spectrogram at 0x7f98dc4e68b0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:6 out of the last 7 calls to <function pad_spectrogram at 0x7f98dc4e68b0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:7 out of the last 8 calls to <function pad_spectrogram at 0x7f98dc4e68b0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:7 out of the last 8 calls to <function pad_spectrogram at 0x7f98dc4e68b0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:7 out of the last 11 calls to <function pad_spectrogram at 0x7f98dc4e68b0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:7 out of the last 11 calls to <function pad_spectrogram at 0x7f98dc4e68b0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:5 out of the last 13 calls to <function pad_spectrogram at 0x7f98dc4e68b0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:5 out of the last 13 calls to <function pad_spectrogram at 0x7f98dc4e68b0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:5 out of the last 14 calls to <function pad_spectrogram at 0x7f98dc4e68b0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:5 out of the last 14 calls to <function pad_spectrogram at 0x7f98dc4e68b0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:5 out of the last 13 calls to <function pad_spectrogram at 0x7f98dc4e68b0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:5 out of the last 13 calls to <function pad_spectrogram at 0x7f98dc4e68b0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-7ef4d0bdd4b8> in <module>
#       1 # Model Training
# ----> 2 model.fit(dn, callbacks=[tbcallback, checkpointcallback], epochs=512, validation_data=dataset_valid, verbose=False)
#
# ~/py/dl_superenv/lib/python3.8/site-packages/tensorflow_core/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     691
#     692     func = self._select_training_loop(x)
# --> 693     return func.fit(
#     694         self,
#     695         x=x,
#
# ~/py/dl_superenv/lib/python3.8/site-packages/tensorflow_core/python/keras/engine/training_v2.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     328                 training_data_iter = iter(training_dataset)
#     329
# --> 330             training_result = run_one_epoch(
#     331                 model,
#     332                 training_data_iter,
#
# ~/py/dl_superenv/lib/python3.8/site-packages/tensorflow_core/python/keras/engine/training_v2.py in run_one_epoch(model, iterator, execution_function, dataset_size, batch_size, strategy, steps_per_epoch, num_samples, mode, training_context, total_epochs)
#     126         step=step, mode=mode, size=current_batch_size) as batch_logs:
#     127       try:
# --> 128         batch_outs = execution_function(iterator)
#     129       except (StopIteration, errors.OutOfRangeError):
#     130         # TODO(kaftan): File bug about tf function and errors.OutOfRangeError?
#
# ~/py/dl_superenv/lib/python3.8/site-packages/tensorflow_core/python/keras/engine/training_v2_utils.py in execution_function(input_fn)
#      96     # `numpy` translates Tensors to values in Eager mode.
#      97     return nest.map_structure(_non_none_constant_value,
# ---> 98                               distributed_function(input_fn))
#      99
#     100   return execution_function
#
# ~/py/dl_superenv/lib/python3.8/site-packages/tensorflow_core/python/eager/def_function.py in __call__(self, *args, **kwds)
#     569         xla_context.Exit()
#     570     else:
# --> 571       result = self._call(*args, **kwds)
#     572
#     573     if tracing_count == self._get_tracing_count():
#
# ~/py/dl_superenv/lib/python3.8/site-packages/tensorflow_core/python/eager/def_function.py in _call(self, *args, **kwds)
#     600       # In this case we have created variables on the first call, so we run the
#     601       # defunned version which is guaranteed to never create variables.
# --> 602       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     603     elif self._stateful_fn is not None:
#     604       # Release the lock early so that multiple threads can perform the call
#
# ~/py/dl_superenv/lib/python3.8/site-packages/tensorflow_core/python/eager/function.py in __call__(self, *args, **kwargs)
#    2412     with self._lock:
#    2413       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2414     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2415
#    2416   @property
#
# ~/py/dl_superenv/lib/python3.8/site-packages/tensorflow_core/python/eager/function.py in _filtered_call(self, args, kwargs)
#    1654       `args` and `kwargs`.
#    1655     """
# -> 1656     return self._call_flat(
#    1657         (t for t in nest.flatten((args, kwargs), expand_composites=True)
#    1658          if isinstance(t, (ops.Tensor,
#
# ~/py/dl_superenv/lib/python3.8/site-packages/tensorflow_core/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1738         and executing_eagerly):
#    1739       # No tape is watching; skip to running the function.
# -> 1740       return self._build_call_outputs(self._inference_function.call(
#    1741           ctx, args, cancellation_manager=cancellation_manager))
#    1742     forward_backward = self._select_forward_and_backward_functions(
#
# ~/py/dl_superenv/lib/python3.8/site-packages/tensorflow_core/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     591       with _InterpolateFunctionError(self):
#     592         if cancellation_manager is None:
# --> 593           outputs = execute.execute(
#     594               str(self.signature.name),
#     595               num_outputs=self._num_outputs,
#
# ~/py/dl_superenv/lib/python3.8/site-packages/tensorflow_core/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57   try:
#      58     ctx.ensure_initialized()
# ---> 59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
# Model Testing
conf_matrix = np.zeros((12, 12), np.uint64)
for di in dn.take(100):
    preds = model.predict(di[0])
    for p, t in zip(np.argmax(preds, axis=-1), np.argmax(di[1], axis=-1)):
        conf_matrix[p, t] += 1
print(conf_matrix)

# %%
# Load Model
model = load_model('saved_models/'+RUN_NAME + '.h5')
